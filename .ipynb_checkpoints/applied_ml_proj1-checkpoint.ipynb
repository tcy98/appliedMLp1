# %% [markdown]
# ## Project 1 - Population Prediction for 2122
# Authors:
# Riley Galante,
# William Chan,
# Tony Tang

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import statsmodels as sm

# %% [markdown]
# ## Data Wrangling

# %%
url = 'https://raw.githubusercontent.com/tcy98/colabDataStoreage/main/population_total_long.csv'
df = pd.read_csv(url)
# Dataset is now stored in a Pandas Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12595 entries, 0 to 12594
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  12595 non-null  object
#  1   Year          12595 non-null  int64
#  2   Count         12595 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 295.3+ KB

# %% [markdown]
# The population dataset from 1960-2017 is loaded in above. For our analysis, we only need the total count for each year, not the total count for each country, each year.

# %%
df[df.Year == 1960].Count.sum()
# Out:
# 3019770047

# %% [markdown]
# This is how we will get the total population value for each year. We sum the count value for each country in a given year.

# %%
population_dict = {1960: 3019770047}
year = 1961
while year <= 2017:
  total_pop = df[df.Year == year].Count.sum()
  population_dict.update({year: total_pop})
  year+=1
df_updated = pd.DataFrame(list(population_dict.items()),columns = ['Year','Count']) 
df_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    58 non-null     int64
#  1   Count   58 non-null     int64
# dtypes: int64(2)
# memory usage: 1.0 KB

# %% [markdown]
# Now that the updated dataframe has been created with the necessary information, time to visualize.

# %%
plt.plot(df_updated.Year, df_updated.Count, 'ro')
plt.xlabel("Year")
plt.ylabel("Population Total (in billions)")
plt.title("Total Population Per Year")
plt.show()

# %% [markdown]
# After visualizing the data, it appears that the trend is relatively linear in the past 60 years. It is important to note that if we had more data from much earlier in time, this trend would most likely be exponential. However, we feel that if we used more data and got the exponential trend, it might influence our model to overestimate the 2122 total population. Especially considering the conclusions of many scientists that the Earth has a maximum capacity for human life that we are quickly approaching, this dataset works better for a more realistic prediction.

# %% [markdown]
# ## Linear Regression Model

# %% [markdown]
# Since the data has a linear trend, we will use a linear regression model to start.

# %%
#80-20 train test split
X_train, X_test, y_train, y_test = train_test_split(df_updated.Year, df_updated.Count, test_size=0.2, random_state=0)

#reshape X values to match parameter requirements of linreg
arr = X_train.values  
X_train = arr.reshape((-1,1))
arr = X_test.values
X_test = arr.reshape((-1,1))

#Fit the model with training data
linreg = LinearRegression().fit(X_train, y_train)

#predict the y_test values using x_test and analyze performance
y_pred = linreg.predict(X_test)
accuracy = r2_score(y_test, y_pred)
print("Score: ", accuracy)
# Out:
# Score:  0.9990664712630442

# %% [markdown]
# In the cell above, a train test split was used to determine if linear regression is a good model for the dataset. It is evident that the model fits the data in that the R2 score is really good, meaning the predicted total population values in the test set are very close to the true population values.

# %%
X = df_updated.Year
y = df_updated.Count

#reshape X values to match parameter requirements of linreg
arr = X.values  
X = arr.reshape((-1,1))

#Fit model with full dataset
linreg = LinearRegression().fit(X, y)

X_predict = np.array([2122])
X_predict = X_predict.reshape((-1,1))

#get 2122 prediction
linreg_prediction = linreg.predict(X_predict)

print("Total Population in 2122:" , "{:.0f}".format(linreg_prediction[0]))
# Out:
# Total Population in 2122: 15895926083

# %% [markdown]
# Linear Regression estimates a population of about 15.9 billion according to the current trend in population growth. This number is likely skewed because we did not have population data available from the past few years in this dataset. Thus, this estimate does not take into account the affect of COVID-19 on the population. Also, as mentioned before, scientists believe there is a cap on the number of humans the earth can support. Currently, that number is at about 9-10 billion, which contradicts our estimate.

# %%
from scipy import optimize
X = df_updated.Year.to_numpy()
y = df_updated.Count.to_numpy()

def objective(x,a,b):
  return a+b*np.log2(x)

popt, _ = optimize.curve_fit(objective, X, y)
a, b = popt
print('y = %.5f + %.5f * log(x)' % (a, b))
# Out:
# y = -1208827723742.10889 + 110791757715.30907 * log(x)

# %%
plt.plot(X, y, 'ro')
x_line = np.arange(min(X), max(X)+100, 1)
y_line = objective(x_line, a, b)
plt.plot(x_line, y_line, 'b-')
plt.xlabel("Year")
plt.ylabel("Population Total (in billions)")
plt.title("Total Population Per Year")
plt.show()

# %%
print("Total Population in 2122: ", "{:.0f}".format(objective(2122, a, b)))
# Out:
# Total Population in 2122:  15555139701

# %% [markdown]
# ## ARIMA Model

# %% [markdown]
# Then, we apply ARIMA model with statsmodels library. An ARIMA model is a class of statistical models for analyzing and forecasting time series data.

# %% [markdown]
# The parameters of the ARIMA model are defined as follows:
#
#
#
# *   p: The number of lag observations included in the model, also called the lag order.
# *   d: The number of times that the raw observations are differenced, also called the degree of differencing.
# *   q: The size of the moving average window, also called the order of moving average.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# First, we apply stationarity test (autocorrelation grpah) on the data.

# %%
from pandas.plotting import autocorrelation_plot

autocorrelation_plot(df_updated)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# The autocorrelation plot shows a clear trend. Idealy, we want it to be more a constant variation. Thus, we apply different degree of order differencing to make data more stationary.
#
# *stationarity means that the statistical properties of a process generating a time series do not change over time*

# %%
df = df_updated

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True,figsize=(10, 10))
axes[0, 0].plot(df.Count); axes[0, 0].set_title('Original Series')
plot_acf(df.Count, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(df.Count.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(df.Count.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(df.Count.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(df.Count.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %% [markdown]
# It shows that a 2nd order differencing should be used in our ARIMA model since it is more constantly changed desipte two spikes.
#
# Thus, d = 2 for ARIMA.
#
# Then, we use auto_arima tool which helps us find the best parameter (p,q) for ARIMA model.

# %%
#install pmdarima  http://alkaline-ml.com/pmdarima/
#Python 3.9 requiered
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (1.8.4)
# Requirement already satisfied: joblib>=0.11 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.13.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (41.4.0)
# Requirement already satisfied: urllib3 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.24.2)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.29.13)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: numpy>=1.19.3 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: scipy>=1.3.2 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: pandas>=0.19 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.25.1)
# Requirement already satisfied: patsy>=0.5.2 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: pytz>=2017.2 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2.8.0)
# Requirement already satisfied: six in /Users/t.t/opt/anaconda3/lib/python3.7/site-packages (from patsy>=0.5.2->statsmodels!=0.12.0,>=0.11->pmdarima) (1.12.0)

# %%
from pmdarima import auto_arima
# stepwise_fit = auto_arima(df_updated['Count'], 
#                           suppress_warnings=True)           
# fit stepwise auto-ARIMA
stepwise_fit = auto_arima(df_updated['Count'], start_p=0, start_q=0,
                             max_p=10, max_q=10, m=1,     # m set to 1 as it cycle annual 
                             seasonal=False,
                             d=2, trace=True,   #second differecing as it shows above
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=True)  # set to stepwise
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1840.126, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1828.333, Time=0.02 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1831.253, Time=0.03 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1841.483, Time=0.01 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=1809.538, Time=0.11 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=1811.547, Time=0.09 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=1811.554, Time=0.31 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1818.202, Time=0.12 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=1813.549, Time=0.13 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=1808.937, Time=0.07 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=1828.578, Time=0.02 sec
#  ARIMA(3,2,0)(0,0,0)[0]             : AIC=1810.869, Time=0.22 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=1810.901, Time=0.07 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=1813.635, Time=0.17 sec
#  ARIMA(3,2,1)(0,0,0)[0]             : AIC=1812.864, Time=0.06 sec
#
# Best model:  ARIMA(2,2,0)(0,0,0)[0]
# Total fit time: 1.438 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   58
# Model:               SARIMAX(2, 2, 0)   Log Likelihood                -901.469
# Date:                Mon, 07 Feb 2022   AIC                           1808.937
# Time:                        13:16:44   BIC                           1815.013
# Sample:                             0   HQIC                          1811.293
#                                  - 58
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0082      0.058     -0.142      0.887      -0.121       0.105
# ar.L2         -0.0041      0.053     -0.077      0.938      -0.108       0.100
# sigma2      5.802e+12   4.14e-15    1.4e+27      0.000     5.8e+12     5.8e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.52   Jarque-Bera (JB):               159.95
# Prob(Q):                              0.47   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.55   Skew:                            -0.48
# Prob(H) (two-sided):                  0.20   Kurtosis:                        11.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.95e+42. Standard errors may be unstable.
# """

# %% [markdown]
# AutoARIMA suggests that (2,2,0) is the best paramter to be used. Compare to other parameter pairs, it has the lowest AIC&BIC which shows it a better model.
#
# *Akaike Information Criterion (AIC). Derived from frequentist probability.
# Bayesian Information Criterion (BIC). Derived from Bayesian probability.*

# %%
from statsmodels.tsa.arima.model import ARIMA
model=ARIMA(df['Count'],order=(2,2,0))
model_fit=model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Count   No. Observations:                   58
# Model:                 ARIMA(2, 2, 0)   Log Likelihood                -901.469
# Date:                Mon, 07 Feb 2022   AIC                           1808.937
# Time:                        13:16:44   BIC                           1815.013
# Sample:                             0   HQIC                          1811.293
#                                  - 58
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0082      0.058     -0.142      0.887      -0.121       0.105
# ar.L2         -0.0041      0.053     -0.077      0.938      -0.108       0.100
# sigma2      5.802e+12   4.14e-15    1.4e+27      0.000     5.8e+12     5.8e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.52   Jarque-Bera (JB):               159.95
# Prob(Q):                              0.47   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.55   Skew:                            -0.48
# Prob(H) (two-sided):                  0.20   Kurtosis:                        11.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.95e+42. Standard errors may be unstable.
# """

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %% [markdown]
# Ploting ARIMA(2,2,0), we notice there is a weird spike at the begining. We cound't find the cause so we ignore the first two outlier prediction.

# %%
# Actual vs Fitted
plt.plot(df_updated.Year[2:],df_updated.Count[2:])
plt.plot(df_updated.Year[2:],model_fit.predict()[2:])
plt.xlabel("Year")
plt.ylabel("Population Total (in billions)")
plt.title("Total Population Per Year")
plt.show()
accuracy2 = r2_score(df_updated.Count[2:], model_fit.predict()[2:])
print("Score: ", accuracy2)
# Out:
# Score:  0.9999967168580383

# %% [markdown]
# Since we use the whole dataset to train the model, our model prediction almost perfectly lined up with the data.

# %%
plt.plot(df_updated.Year[2:],df_updated.Count[2:])
plt.plot(df_updated.Year[2:],model_fit.predict()[2:])
plt.plot(range(2017,2122),model_fit.forecast(105))
plt.xlabel("Year")
plt.ylabel("Population Total (in billions)")
plt.title("Total Population Per Year")
plt.show()

# %%
#prediction for 2122
model_fit.forecast(2122-2017)[2122-1960]
# Out:
# 16407367396.015478

# %% [markdown]
# ARIMA model predicts 1.6e10 as the population in 2122, which is very close to our linear regression model prediction. It does make sense since ARIMA is a linear/regression-type equation and our train data is very close to a linear graph.
